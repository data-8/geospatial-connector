# %% [markdown]
# ## Extracting and Mapping Place Names
# ### This notebook demonstrates the power of and problems with automated Geoparsing.
#
# In this notebook we:
# - fetch a text from project gutenberg
# - extract place names from that text with NLTK (geoparsing)
# - geocode the place names with geopy / geonames (a type of georeferencing)
# - map the place locations with datascience maps module
#
# Learning goals:
# - Think about the differences in place name vs. coordinate representations of locations.
# - Consider some of the things you can do with the place names once they are geocoded.

# %%
# Run but don't change!
from datascience import *
from datascience.predicates import are
import numpy as np
from scipy import stats
from scipy import misc

from nltk import ne_chunk, pos_tag, word_tokenize
from nltk.tree import Tree

from urllib.request import urlopen 
import re
def read_url(url): 
    return re.sub('\\s+', ' ', urlopen(url).read().decode())

from itertools import groupby

from geopy.geocoders import GeoNames

# %%
# Create an NLTK location parsing function
# Source: http://stackoverflow.com/questions/31836058/nltk-named-entity-recognition-to-a-python-list
def get_continuous_chunks(text):
    chunked = ne_chunk(pos_tag(word_tokenize(text)))
    #print(chunked)
    prev = None
    continuous_chunk = []
    current_chunk = []
    for i in chunked:
        if type(i) == Tree and (str(i).find('GPE') >=0):
            #print(i)
            current_chunk.append(" ".join([token for token, pos in i.leaves()]))
            #print("......", current_chunk)
        elif current_chunk:
            named_entity = " ".join(current_chunk)
            #if named_entity not in continuous_chunk:
            #    continuous_chunk.append(named_entity)
            #    current_chunk = []
            continuous_chunk.append(named_entity)
            current_chunk = []
        else:
            continue
    return continuous_chunk

# %%
# Test the NLTK location parsing function
my_sent = "Washington -- In the wake of a string of abuses by New York police officers in the 1990s, Loretta E. Lynch the top federal prosecutor in Brooklyn, spoke forcefully about the pain of a broken trust that African-Americans felt and said the responsibility for repairing generations of miscommunication and mistrust fell to law enforcement. Similar feelings were reported in Washington."

my_sent
# Out:
# 'Washington -- In the wake of a string of abuses by New York police officers in the 1990s, Loretta E. Lynch the top federal prosecutor in Brooklyn, spoke forcefully about the pain of a broken trust that African-Americans felt and said the responsibility for repairing generations of miscommunication and mistrust fell to law enforcement. Similar feelings were reported in Washington.'

# %%
my_locs = get_continuous_chunks(my_sent)

# %%
loc_count =  [(k, len(list(g))) for k, g in groupby(sorted(my_locs))]
print(loc_count)
(a,b) = zip(*loc_count) # this returns two lists that can then be columns in tables
print(a)
print(b)
# Out:
# [('Brooklyn', 1), ('New York', 1), ('Washington', 2)]
# ('Brooklyn', 'New York', 'Washington')
# (1, 1, 2)

# %%
# Define a geocoder 
# IMPORTANT ! - this uses my username!! need to change that to your own!
gloc = GeoNames(country_bias=None, username='XXXXXX', timeout=10, proxies=None, user_agent=None)

# %%
# Test the geocoder
x = gloc.geocode('Berkeley')
x
# Out:
# Location(Berkeley, CA, US, (37.87159, -122.27275, 0.0))

# %%
# geocoder output
print(x.raw)
print(x.raw['name'])
print(x.latitude)
# Out:
# {'fclName': 'city, village,...', 'lng': '-122.27275', 'adminCode1': 'CA', 'toponymName': 'Berkeley', 'fcode': 'PPL', 'fcl': 'P', 'lat': '37.87159', 'population': 112580, 'name': 'Berkeley', 'countryName': 'United States', 'countryCode': 'US', 'geonameId': 5327684, 'countryId': '6252001', 'adminName1': 'California', 'fcodeName': 'populated place'}
# Berkeley
# 37.87159

# %%
# Read in a text to Geoparse

#huck_finn_url = 'http://www.gutenberg.org/cache/epub/76/pg76.txt'
#huck_finn_text = read_url(huck_finn_url)
#text_url = huck_finn_url # NOT good for geocoding

#text_url = 'http://www.gutenberg.org/cache/epub/541/pg541.txt' # age of innocence
#text_url = 'http://www.gutenberg.org/cache/epub/3029/pg3029.txt'
text_url = 'http://www.gutenberg.org/cache/epub/103/pg103.txt' #around the world in 80 days

the_text = read_url(text_url)

# %%
# this can take a few minutes...
text_locs = get_continuous_chunks(the_text)

# %%
loc_count =  [(k, len(list(g))) for k, g in groupby(sorted(text_locs))]

# %%
loc_count
# Out:
# [('Aden', 5),
#  ('Africa', 3),
#  ('Ahmehnagara', 1),
#  ('Allahabad', 9),
#  ('America', 14),
#  ('American', 27),
#  ('Americans', 3),
#  ('Anam', 1),
#  ('Aouda', 33),
#  ('Apiece', 1),
#  ('Arabic', 1),
#  ('Armenian', 1),
#  ('Asia', 4),
#  ('Asian', 1),
#  ('Athens', 1),
#  ('Auburn', 1),
#  ('Banyans', 1),
#  ('Barnum', 1),
#  ('Behar', 2),
#  ('Benares', 1),
#  ('Bengal', 4),
#  ('Biblical', 1),
#  ('Birmingham', 1),
#  ('Bombay', 54),
#  ('Bordeaux', 4),
#  ('Brahmins', 1),
#  ('Brazil', 1),
#  ('Brigham Young', 1),
#  ('Brindisi', 9),
#  ('British', 7),
#  ('British India', 1),
#  ('Broadway', 2),
#  ('Buddhism', 1),
#  ('Buddhist', 1),
#  ('Bundelcund', 7),
#  ('Burdwan', 1),
#  ('Burhampoor', 1),
#  ('Buxar', 1),
#  ('Byronic', 1),
#  ('Calais', 2),
#  ('Calcutta', 29),
#  ('California', 3),
#  ('Californian', 1),
#  ('Cambray', 1),
#  ('Cancer', 1),
#  ('Cani', 1),
#  ('Captain', 1),
#  ('Captain Speedy', 1),
#  ('Cardiff', 1),
#  ('Carnatic', 1),
#  ('Certain', 1),
#  ('Ceylon', 1),
#  ('Ceylonese', 1),
#  ('Chancery', 1),
#  ('Chandernagor', 2),
#  ('Cheshire', 1),
#  ('Chicago', 8),
#  ('Chili', 1),
#  ('China', 13),
#  ('Chinamen', 2),
#  ('Chinese', 16),
#  ('Chupenie', 1),
#  ('Colfax', 1),
#  ('Colonel', 2),
#  ('Colorado', 3),
#  ('Columbus', 1),
#  ('Court', 1),
#  ('Crown', 1),
#  ('December', 1),
#  ('Denver', 1),
#  ('Dover', 1),
#  ('Dublin', 3),
#  ('Dutch', 2),
#  ('Dutchmen', 1),
#  ('Egypt', 2),
#  ('Egyptian', 1),
#  ('Elephanta', 1),
#  ('Enfield', 1),
#  ('England', 30),
#  ('English', 56),
#  ('Europe', 13),
#  ('European', 11),
#  ('Europeans', 2),
#  ('Fix', 14),
#  ('Flanagan', 1),
#  ('Fogg', 3),
#  ('France', 3),
#  ('Fremont', 1),
#  ('French', 11),
#  ('Frenchman', 6),
#  ('Ganges', 3),
#  ('Germany', 1),
#  ('God', 1),
#  ('Gothic', 1),
#  ('Great', 2),
#  ('Greenwich', 1),
#  ('Havre', 2),
#  ('Himalaya', 1),
#  ('Hindoo', 1),
#  ('Holland', 2),
#  ('Hong', 1),
#  ('Hong Kong', 57),
#  ('Hottentots', 1),
#  ('Hudson', 3),
#  ('INDIRECT', 1),
#  ('Illinois', 3),
#  ('Independence', 1),
#  ('India', 34),
#  ('Indian', 31),
#  ('Indian Ocean', 1),
#  ('Indiana', 1),
#  ('Indians', 17),
#  ('Indus', 1),
#  ('Iowa', 2),
#  ('Irish', 2),
#  ('Israel', 1),
#  ('Italian', 1),
#  ('Italiens', 1),
#  ('Japan', 13),
#  ('Japanese', 22),
#  ('Japanese Empire', 1),
#  ('Jean', 1),
#  ('Jordan', 2),
#  ('Juggernaut', 3),
#  ('Kallenger', 1),
#  ('Kama', 1),
#  ('Kandallah', 1),
#  ('Kanherian', 1),
#  ('Kansas', 1),
#  ('Kearney', 1),
#  ('Kent', 1),
#  ('Khandeish', 2),
#  ('Kholby', 2),
#  ('Kiouni', 5),
#  ('Kirkland', 1),
#  ('Liverpool', 3),
#  ('London', 62),
#  ('Londoner', 1),
#  ('Long', 1),
#  ('Long Island', 1),
#  ('Macao', 2),
#  ('Madras', 3),
#  ('Malacca', 3),
#  ('Malays', 1),
#  ('Mandiboy', 1),
#  ('Marylebone', 1),
#  ('Mexico', 1),
#  ('Middle Ages', 1),
#  ('Mikado', 1),
#  ('Mississippi', 2),
#  ('Missouri', 1),
#  ('Mongolia', 9),
#  ('Mormon', 5),
#  ('Mormons', 2),
#  ('Murshedabad', 1),
#  ('Nagasaki', 2),
#  ('Nankin', 1),
#  ('Nebraska', 1),
#  ('Neptune', 1),
#  ('Nevada', 2),
#  ('New Holland', 1),
#  ('New Jersey', 1),
#  ('New York', 28),
#  ('Newfoundland', 1),
#  ('Nizam', 1),
#  ('North America', 1),
#  ('North Platte', 1),
#  ('Northern', 1),
#  ('Norway', 1),
#  ('Oakland', 1),
#  ('Ohio', 3),
#  ('Omaha', 12),
#  ('Oregon', 1),
#  ('Pall Mall', 2),
#  ('Paris', 9),
#  ('Parisian', 2),
#  ('Parsee', 7),
#  ('Passepartout', 51),
#  ('Pennsylvania', 1),
#  ('Phileas Fogg', 1),
#  ('Pillaji', 6),
#  ('Portuguese', 2),
#  ('Pounah', 1),
#  ('Ralph', 1),
#  ('Ramayana', 1),
#  ('Rangoon', 4),
#  ('Reform', 5),
#  ('Regent', 1),
#  ('Rothal', 1),
#  ('Sacramento', 1),
#  ('Salcette', 2),
#  ('San', 8),
#  ('San Francisco', 6),
#  ('Saville', 9),
#  ('Saville Row', 5),
#  ('Scotch', 1),
#  ('Scotland', 1),
#  ('Scotland Yard', 1),
#  ('Sedgwick', 1),
#  ('Shanghai', 13),
#  ('Sheridan', 1),
#  ('Sindes', 1),
#  ('Singapore', 9),
#  ('Sioux', 4),
#  ('Sir', 1),
#  ('Solomon', 1),
#  ('Somalis', 1),
#  ('South', 1),
#  ('Southampton', 1),
#  ('Stuart', 1),
#  ('Suez', 7),
#  ('Sumatra', 1),
#  ('Surat', 1),
#  ('Sweden', 1),
#  ('Sydenham', 1),
#  ('Tannah', 1),
#  ('Tears', 1),
#  ('Temple', 1),
#  ('Thanks', 3),
#  ('Times', 1),
#  ('Tycoon', 1),
#  ('U.S.', 3),
#  ('United States', 17),
#  ('Uranus', 1),
#  ('Utah', 3),
#  ('Vermont', 2),
#  ('Victoria', 2),
#  ('Vicvarcarma', 1),
#  ('Wait', 1),
#  ('West', 1),
#  ('Wyoming', 1),
#  ('Yeddo', 2),
#  ('Yokohama', 19)]

# %%
# Create an empty table
loc_table = Table(['place','count'])

# %%
# Put the location data into the table
(loc_table['place'], loc_table['count']) = zip(*loc_count)

# %%
loc_table
# Out:
# place       | count
# Aden        | 5
# Africa      | 3
# Ahmehnagara | 1
# Allahabad   | 9
# America     | 14
# American    | 27
# Americans   | 3
# Anam        | 1
# Aouda       | 33
# Apiece      | 1
# ... (223 rows omitted)

# %%
# Optional and arbitrary - remove minor mentions
top_locs = loc_table.where(loc_table['count'] > 5)
top_locs.sort('count', descending=True).show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>place</th> <th>count</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>London       </td> <td>62   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Hong Kong    </td> <td>57   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>English      </td> <td>56   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Bombay       </td> <td>54   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Passepartout </td> <td>51   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>India        </td> <td>34   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Aouda        </td> <td>33   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Indian       </td> <td>31   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>England      </td> <td>30   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Calcutta     </td> <td>29   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>New York     </td> <td>28   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>American     </td> <td>27   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Japanese     </td> <td>22   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Yokohama     </td> <td>19   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>United States</td> <td>17   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Indians      </td> <td>17   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Chinese      </td> <td>16   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Fix          </td> <td>14   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>America      </td> <td>14   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Shanghai     </td> <td>13   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Japan        </td> <td>13   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Europe       </td> <td>13   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>China        </td> <td>13   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Omaha        </td> <td>12   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>French       </td> <td>11   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>European     </td> <td>11   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Singapore    </td> <td>9    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Saville      </td> <td>9    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Paris        </td> <td>9    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Mongolia     </td> <td>9    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Brindisi     </td> <td>9    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Allahabad    </td> <td>9    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>San          </td> <td>8    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Chicago      </td> <td>8    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Suez         </td> <td>7    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Parsee       </td> <td>7    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Bundelcund   </td> <td>7    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>British      </td> <td>7    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>San Francisco</td> <td>6    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Pillaji      </td> <td>6    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Frenchman    </td> <td>6    </td>
#         </tr>
#     </tbody>
# </table>

# %%
# Examining some of the non-loc locs and how the geocoder will disambiguate
x = gloc.geocode('Portuguese')

# %%
x.raw
# Out:
# {'adminCode1': '00',
#  'adminName1': '',
#  'countryCode': 'MZ',
#  'countryId': '1036973',
#  'countryName': 'Mozambique',
#  'fcl': 'A',
#  'fclName': 'country, state, region,...',
#  'fcode': 'PCLI',
#  'fcodeName': 'independent political entity',
#  'geonameId': 1036973,
#  'lat': '-18.25',
#  'lng': '35',
#  'name': 'Mozambique',
#  'population': 22061451,
#  'toponymName': 'Republic of Mozambique'}

# %%
if (x.raw['fcode'] == 'PPLC'): { print ('yes')}

# %%
# Half-hearted attempt to clean up locations - an example of how one might move forward..
# Could use regular expressions to clean this.
# remove places ending in "an", "ans", "ish", "ese", and "French" 
top_locs = top_locs.where((top_locs['place'] !=('French')) & (top_locs['place'] !=('American')))
top_locs = top_locs.where((top_locs['place'] !=('British')) & (top_locs['place'] !=('English')))
top_locs = top_locs.where((top_locs['place'] !=('French')) & (top_locs['place'] !=('American')))
top_locs = top_locs.where((top_locs['place'] !=('Chinese')) & (top_locs['place'] !=('Portuguese')))
top_locs = top_locs.where((top_locs['place'] !=('Indian')) & (top_locs['place'] !=('Indians')))
top_locs = top_locs.where((top_locs['place'] !=('Japanese')) & (top_locs['place'] !=('Mexican')))
top_locs = top_locs.where((top_locs['place'] !=('Servian'))) 
top_locs.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>place</th> <th>count</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Allahabad    </td> <td>9    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>America      </td> <td>14   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Aouda        </td> <td>33   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Bombay       </td> <td>54   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Brindisi     </td> <td>9    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Bundelcund   </td> <td>7    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Calcutta     </td> <td>29   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Chicago      </td> <td>8    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>China        </td> <td>13   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>England      </td> <td>30   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Europe       </td> <td>13   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>European     </td> <td>11   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Fix          </td> <td>14   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Frenchman    </td> <td>6    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Hong Kong    </td> <td>57   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>India        </td> <td>34   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Japan        </td> <td>13   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>London       </td> <td>62   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Mongolia     </td> <td>9    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>New York     </td> <td>28   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Omaha        </td> <td>12   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Paris        </td> <td>9    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Parsee       </td> <td>7    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Passepartout </td> <td>51   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Pillaji      </td> <td>6    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>San          </td> <td>8    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>San Francisco</td> <td>6    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Saville      </td> <td>9    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Shanghai     </td> <td>13   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Singapore    </td> <td>9    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Suez         </td> <td>7    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>United States</td> <td>17   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Yokohama     </td> <td>19   </td>
#         </tr>
#     </tbody>
# </table>

# %%
# A function to geocode the places one by one and 
# return output that will load nicely into our table
def getGeocodeInfo(place):
    print('geocoding...', place)
    x = gloc.geocode(place)
    if(x != None):
        mystuff = [float(x.raw['lng']), float(x.raw['lat']), x.raw['fcl'], x.raw['fclName']]
    else:
        #what to return whn a place can't be geocoded
        mystuff = [0,0,"none","none"]
        
    return mystuff

# %%
# testing function
getGeocodeInfo('Berkeley')
# Out:
# geocoding... Berkeley
# [-122.27275, 37.87159, 'P', 'city, village,...']

# %%
# test data that won't geocode
t = gloc.geocode('Bundelcund')
print(t)
#print(t.raw)

getGeocodeInfo('Bundelcund')
# Out:
# None
# geocoding... Bundelcund
# [0, 0, 'none', 'none']

# %%
## THIS DIDN"T WORK! But would be nice to git it to
#(loc_table['place'], loc_table['count']) = zip(*loc_count)
#(top_locs['lng'], top_locs['lat'], top_locs['fpl'], top_locs['fcl_name']) = top_locs.apply(lambda x: zip(*getGeocodeInfo(x)), ['place'])

# %%
# GEOCODE ALL PLACES IN THE TOP_LOCS TABLE
x = []
def getAll():
    for i in top_locs['place']:
        x.append(getGeocodeInfo(i))
    return x

# %%
x = getAll()
x
# Out:
# geocoding... Allahabad
# geocoding... America
# geocoding... Aouda
# geocoding... Bombay
# geocoding... Brindisi
# geocoding... Bundelcund
# geocoding... Calcutta
# geocoding... Chicago
# geocoding... China
# geocoding... England
# geocoding... Europe
# geocoding... European
# geocoding... Fix
# geocoding... Frenchman
# geocoding... Hong Kong
# geocoding... India
# geocoding... Japan
# geocoding... London
# geocoding... Mongolia
# geocoding... New York
# geocoding... Omaha
# geocoding... Paris
# geocoding... Parsee
# geocoding... Passepartout
# geocoding... Pillaji
# geocoding... San
# geocoding... San Francisco
# geocoding... Saville
# geocoding... Shanghai
# geocoding... Singapore
# geocoding... Suez
# geocoding... United States
# geocoding... Yokohama
# [[81.84322, 25.44478, 'P', 'city, village,...'],
#  [-105.64453, 54.77535, 'L', 'parks,area, ...'],
#  [0.82273, 35.18509, 'P', 'city, village,...'],
#  [72.88261, 19.07283, 'P', 'city, village,...'],
#  [17.93607, 40.63215, 'P', 'city, village,...'],
#  [0, 0, 'none', 'none'],
#  [88.36304, 22.56263, 'P', 'city, village,...'],
#  [-87.65005, 41.85003, 'P', 'city, village,...'],
#  [105.0, 35.0, 'A', 'country, state, region,...'],
#  [-70.3064, 44.2056, 'A', 'country, state, region,...'],
#  [28.38867, 51.72703, 'L', 'parks,area, ...'],
#  [15.97753, 45.81313, 'P', 'city, village,...'],
#  [3.66832, 45.14264, 'P', 'city, village,...'],
#  [174.5275, -35.86083, 'T', 'mountain,hill,rock,... '],
#  [114.15769, 22.28552, 'P', 'city, village,...'],
#  [79.0, 22.0, 'A', 'country, state, region,...'],
#  [139.75309, 35.68536, 'A', 'country, state, region,...'],
#  [-0.12574, 51.50853, 'P', 'city, village,...'],
#  [105.0, 46.0, 'A', 'country, state, region,...'],
#  [-74.00597, 40.71427, 'P', 'city, village,...'],
#  [-95.93779, 41.25861, 'P', 'city, village,...'],
#  [2.3488, 48.85341, 'P', 'city, village,...'],
#  [147.08333, -7.01667, 'T', 'mountain,hill,rock,... '],
#  [0, 0, 'none', 'none'],
#  [0, 0, 'none', 'none'],
#  [-89.18718, 13.68935, 'P', 'city, village,...'],
#  [-84.12934, 9.99299, 'P', 'city, village,...'],
#  [-81.27189, 47.61848, 'H', 'stream, lake, ...'],
#  [121.45806, 31.22222, 'P', 'city, village,...'],
#  [103.85007, 1.28967, 'P', 'city, village,...'],
#  [32.52627, 29.97371, 'P', 'city, village,...'],
#  [-98.5, 39.76, 'A', 'country, state, region,...'],
#  [139.6425, 35.44778, 'P', 'city, village,...']]

# %%
#MAKE SURE THE NUMBER OF GEOCODED LOCS IS SAME AS NUMBER OF ROWS IN OUR TABLE
top_locs.num_rows == len(x)
# Out:
# True

# %%
# Add geocoded location data to the table
(top_locs['longitude'], top_locs['latitude'], top_locs['fpl'], top_locs['fcl_name']) = zip(*x)
top_locs.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>place</th> <th>count</th> <th>longitude</th> <th>latitude</th> <th>fpl</th> <th>fcl_name</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Allahabad    </td> <td>9    </td> <td>81.8432  </td> <td>25.4448 </td> <td>P   </td> <td>city, village,...         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>America      </td> <td>14   </td> <td>-105.645 </td> <td>54.7754 </td> <td>L   </td> <td>parks,area, ...           </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Aouda        </td> <td>33   </td> <td>0.82273  </td> <td>35.1851 </td> <td>P   </td> <td>city, village,...         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Bombay       </td> <td>54   </td> <td>72.8826  </td> <td>19.0728 </td> <td>P   </td> <td>city, village,...         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Brindisi     </td> <td>9    </td> <td>17.9361  </td> <td>40.6322 </td> <td>P   </td> <td>city, village,...         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Bundelcund   </td> <td>7    </td> <td>0        </td> <td>0       </td> <td>none</td> <td>none                      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Calcutta     </td> <td>29   </td> <td>88.363   </td> <td>22.5626 </td> <td>P   </td> <td>city, village,...         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Chicago      </td> <td>8    </td> <td>-87.65   </td> <td>41.85   </td> <td>P   </td> <td>city, village,...         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>China        </td> <td>13   </td> <td>105      </td> <td>35      </td> <td>A   </td> <td>country, state, region,...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>England      </td> <td>30   </td> <td>-70.3064 </td> <td>44.2056 </td> <td>A   </td> <td>country, state, region,...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Europe       </td> <td>13   </td> <td>28.3887  </td> <td>51.727  </td> <td>L   </td> <td>parks,area, ...           </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>European     </td> <td>11   </td> <td>15.9775  </td> <td>45.8131 </td> <td>P   </td> <td>city, village,...         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Fix          </td> <td>14   </td> <td>3.66832  </td> <td>45.1426 </td> <td>P   </td> <td>city, village,...         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Frenchman    </td> <td>6    </td> <td>174.528  </td> <td>-35.8608</td> <td>T   </td> <td>mountain,hill,rock,...    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Hong Kong    </td> <td>57   </td> <td>114.158  </td> <td>22.2855 </td> <td>P   </td> <td>city, village,...         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>India        </td> <td>34   </td> <td>79       </td> <td>22      </td> <td>A   </td> <td>country, state, region,...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Japan        </td> <td>13   </td> <td>139.753  </td> <td>35.6854 </td> <td>A   </td> <td>country, state, region,...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>London       </td> <td>62   </td> <td>-0.12574 </td> <td>51.5085 </td> <td>P   </td> <td>city, village,...         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Mongolia     </td> <td>9    </td> <td>105      </td> <td>46      </td> <td>A   </td> <td>country, state, region,...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>New York     </td> <td>28   </td> <td>-74.006  </td> <td>40.7143 </td> <td>P   </td> <td>city, village,...         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Omaha        </td> <td>12   </td> <td>-95.9378 </td> <td>41.2586 </td> <td>P   </td> <td>city, village,...         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Paris        </td> <td>9    </td> <td>2.3488   </td> <td>48.8534 </td> <td>P   </td> <td>city, village,...         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Parsee       </td> <td>7    </td> <td>147.083  </td> <td>-7.01667</td> <td>T   </td> <td>mountain,hill,rock,...    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Passepartout </td> <td>51   </td> <td>0        </td> <td>0       </td> <td>none</td> <td>none                      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Pillaji      </td> <td>6    </td> <td>0        </td> <td>0       </td> <td>none</td> <td>none                      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>San          </td> <td>8    </td> <td>-89.1872 </td> <td>13.6893 </td> <td>P   </td> <td>city, village,...         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>San Francisco</td> <td>6    </td> <td>-84.1293 </td> <td>9.99299 </td> <td>P   </td> <td>city, village,...         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Saville      </td> <td>9    </td> <td>-81.2719 </td> <td>47.6185 </td> <td>H   </td> <td>stream, lake, ...         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Shanghai     </td> <td>13   </td> <td>121.458  </td> <td>31.2222 </td> <td>P   </td> <td>city, village,...         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Singapore    </td> <td>9    </td> <td>103.85   </td> <td>1.28967 </td> <td>P   </td> <td>city, village,...         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Suez         </td> <td>7    </td> <td>32.5263  </td> <td>29.9737 </td> <td>P   </td> <td>city, village,...         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>United States</td> <td>17   </td> <td>-98.5    </td> <td>39.76   </td> <td>A   </td> <td>country, state, region,...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Yokohama     </td> <td>19   </td> <td>139.643  </td> <td>35.4478 </td> <td>P   </td> <td>city, village,...         </td>
#         </tr>
#     </tbody>
# </table>

# %%
# Set the color and radius for each point we will map
top_locs['radius'] = 1000 * top_locs['count']
top_locs['color'] = 'red'
top_locs
# Out:
# place      | count | longitude | latitude | fpl  | fcl_name                   | radius | color
# Allahabad  | 9     | 81.8432   | 25.4448  | P    | city, village,...          | 9000   | red
# America    | 14    | -105.645  | 54.7754  | L    | parks,area, ...            | 14000  | red
# Aouda      | 33    | 0.82273   | 35.1851  | P    | city, village,...          | 33000  | red
# Bombay     | 54    | 72.8826   | 19.0728  | P    | city, village,...          | 54000  | red
# Brindisi   | 9     | 17.9361   | 40.6322  | P    | city, village,...          | 9000   | red
# Bundelcund | 7     | 0         | 0        | none | none                       | 7000   | red
# Calcutta   | 29    | 88.363    | 22.5626  | P    | city, village,...          | 29000  | red
# Chicago    | 8     | -87.65    | 41.85    | P    | city, village,...          | 8000   | red
# China      | 13    | 105       | 35       | A    | country, state, region,... | 13000  | red
# England    | 30    | -70.3064  | 44.2056  | A    | country, state, region,... | 30000  | red
# ... (23 rows omitted)

# %%
# Creat descriptive text for popup
top_locs['description'] = top_locs.apply(lambda x,y: "%s, %s mentions"% (x, str(y)), ['place', 'count'])

# %%
# Select only the columns that will be used to map the points
top_locs = top_locs.where(top_locs['latitude'] != 0)  # couldnt combine these two conditions
top_locs = top_locs.where(top_locs['longitude'] != 0) # assuming 0,0 not a valid locatoin
locmap = top_locs.select(['latitude', 'longitude','description','color','radius'])
locmap
# Out:
# latitude | longitude | description           | color | radius
# 25.4448  | 81.8432   | Allahabad, 9 mentions | red   | 9000
# 54.7754  | -105.645  | America, 14 mentions  | red   | 14000
# 35.1851  | 0.82273   | Aouda, 33 mentions    | red   | 33000
# 19.0728  | 72.8826   | Bombay, 54 mentions   | red   | 54000
# 40.6322  | 17.9361   | Brindisi, 9 mentions  | red   | 9000
# 22.5626  | 88.363    | Calcutta, 29 mentions | red   | 29000
# 41.85    | -87.65    | Chicago, 8 mentions   | red   | 8000
# 35       | 105       | China, 13 mentions    | red   | 13000
# 44.2056  | -70.3064  | England, 30 mentions  | red   | 30000
# 51.727   | 28.3887   | Europe, 13 mentions   | red   | 13000
# ... (20 rows omitted)

# %%
# Create the map
locmap['radius'] =  10000 * top_locs['count']
Circle.map_table(locmap)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_469f504e555b4bffaff66f659f488eb6&quot; style=&quot;width: 960px; height: 500px&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', {
#           maxZoom: 17,
#           minZoom: -1,
#           attribution: 'Map data (c) <a href=&quot;http://openstreetmap.org&quot;>OpenStreetMap</a> contributors'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Bounding box.
#       */
#       var southWest = L.latLng(-90, -180),
#           northEast = L.latLng(90, 180),
#           bounds = L.latLngBounds(southWest, northEast);
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_469f504e555b4bffaff66f659f488eb6', {
#                                        center:[9.45726, 34.441485],
#                                        zoom: 1,
#                                        maxBounds: bounds,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       //add the clustered markers to the group anyway
#       map.addLayer(clusteredmarkers);
#
#
#
#
#       var circle_1 = L.circle([25.44478, 81.84322], 90000, {
#                             color: 'None',
#                             fillColor: 'red',
#                             fillOpacity: 0.6
#                             });
#       circle_1.bindPopup(&quot;Allahabad, 9 mentions&quot;);
#       circle_1._popup.options.maxWidth = 300;
#       map.addLayer(circle_1)
#
#       var circle_2 = L.circle([54.77535, -105.64453], 140000, {
#                             color: 'None',
#                             fillColor: 'red',
#                             fillOpacity: 0.6
#                             });
#       circle_2.bindPopup(&quot;America, 14 mentions&quot;);
#       circle_2._popup.options.maxWidth = 300;
#       map.addLayer(circle_2)
#
#       var circle_3 = L.circle([35.18509, 0.82273], 330000, {
#                             color: 'None',
#                             fillColor: 'red',
#                             fillOpacity: 0.6
#                             });
#       circle_3.bindPopup(&quot;Aouda, 33 mentions&quot;);
#       circle_3._popup.options.maxWidth = 300;
#       map.addLayer(circle_3)
#
#       var circle_4 = L.circle([19.07283, 72.88261], 540000, {
#                             color: 'None',
#                             fillColor: 'red',
#                             fillOpacity: 0.6
#                             });
#       circle_4.bindPopup(&quot;Bombay, 54 mentions&quot;);
#       circle_4._popup.options.maxWidth = 300;
#       map.addLayer(circle_4)
#
#       var circle_5 = L.circle([40.63215, 17.93607], 90000, {
#                             color: 'None',
#                             fillColor: 'red',
#                             fillOpacity: 0.6
#                             });
#       circle_5.bindPopup(&quot;Brindisi, 9 mentions&quot;);
#       circle_5._popup.options.maxWidth = 300;
#       map.addLayer(circle_5)
#
#       var circle_6 = L.circle([22.56263, 88.36304], 290000, {
#                             color: 'None',
#                             fillColor: 'red',
#                             fillOpacity: 0.6
#                             });
#       circle_6.bindPopup(&quot;Calcutta, 29 mentions&quot;);
#       circle_6._popup.options.maxWidth = 300;
#       map.addLayer(circle_6)
#
#       var circle_7 = L.circle([41.85003, -87.65005], 80000, {
#                             color: 'None',
#                             fillColor: 'red',
#                             fillOpacity: 0.6
#                             });
#       circle_7.bindPopup(&quot;Chicago, 8 mentions&quot;);
#       circle_7._popup.options.maxWidth = 300;
#       map.addLayer(circle_7)
#
#       var circle_8 = L.circle([35.0, 105.0], 130000, {
#                             color: 'None',
#                             fillColor: 'red',
#                             fillOpacity: 0.6
#                             });
#       circle_8.bindPopup(&quot;China, 13 mentions&quot;);
#       circle_8._popup.options.maxWidth = 300;
#       map.addLayer(circle_8)
#
#       var circle_9 = L.circle([44.2056, -70.3064], 300000, {
#                             color: 'None',
#                             fillColor: 'red',
#                             fillOpacity: 0.6
#                             });
#       circle_9.bindPopup(&quot;England, 30 mentions&quot;);
#       circle_9._popup.options.maxWidth = 300;
#       map.addLayer(circle_9)
#
#       var circle_10 = L.circle([51.72703, 28.38867], 130000, {
#                             color: 'None',
#                             fillColor: 'red',
#                             fillOpacity: 0.6
#                             });
#       circle_10.bindPopup(&quot;Europe, 13 mentions&quot;);
#       circle_10._popup.options.maxWidth = 300;
#       map.addLayer(circle_10)
#
#       var circle_11 = L.circle([45.81313, 15.97753], 110000, {
#                             color: 'None',
#                             fillColor: 'red',
#                             fillOpacity: 0.6
#                             });
#       circle_11.bindPopup(&quot;European, 11 mentions&quot;);
#       circle_11._popup.options.maxWidth = 300;
#       map.addLayer(circle_11)
#
#       var circle_12 = L.circle([45.14264, 3.66832], 140000, {
#                             color: 'None',

# %%
top_locs.where('place','San Francisco')
# Out:
# place         | count | longitude | latitude | fpl  | fcl_name          | radius | color | description
# San Francisco | 6     | -84.1293  | 9.99299  | P    | city, village,... | 6000   | red   | San Francisco, 6 mentions

# %%
gloc.geocode('San Francisco')
# Out:
# Location(San Francisco, 04, CR, (9.99299, -84.12934, 0.0))

# %%
gloc.geocode('San Francisco, CA')
# Out:
# Location(San Francisco, CA, US, (37.77493, -122.41942, 0.0))

# %% [markdown]
# ## Questions:
#
# - Name some of the characteristics of place names that geocoded well and of those that did poorly.
# - Name some of the reasons why place name geoparsing (location named entity recognition NER) is difficult.
# - Similarly why is place name "data cleaning" difficult.
# - What are some of the benefits to automated geoparsing?
# - What types of texts would geocode better than others? worse?
# - What are the alternatives to automated geoparsing?
# - Discuss the difference between georeferinging that big city across the bay as 'San Francisco' vs. 37.77493, '-122.41942'.
# - What can you do with the results of automated geoparsing? How might they be used?
